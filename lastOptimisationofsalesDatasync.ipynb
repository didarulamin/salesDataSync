# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: requests==2.31.0 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: pymongo==4.7.2 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (4.7.2)
# Requirement already satisfied: python-dotenv==1.0.1 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: schedule==1.2.1 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\didar\anaconda3\lib\site-packages (from pymongo==4.7.2->-r requirements.txt (line 2)) (2.7.0)

# %%
# !pip install -r requirements.txt
import requests
from pymongo import MongoClient, UpdateOne
import time
from datetime import datetime, timezone
import schedule
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# MongoDB Connection
MONGO_URI = os.getenv("MONGO_URI")
DATABASE_NAME = "Daftra"
COLLECTION_NAME = "products"

client = MongoClient(MONGO_URI)
db = client[DATABASE_NAME]
collection = db[COLLECTION_NAME]

# API Configuration
API_URL_PRODUCTS = "https://amamamed.daftra.com/api2/products"
API_URL_TRANSACTIONS = "https://amamamed.daftra.com/api2/stock_transactions"
API_URL_ORDERS = "https://amamamed.daftra.com/v2/api/entity/invoice/list/-1"
API_URL_ORDERS_ZID = "https://api.zid.sa/v1/managers/store/orders/{order_id}/view"

# Environment Variables
APIKEY = os.getenv("APIKEY")
AUTH_TOKEN = os.getenv("AUTH_TOKEN")
MANAGER_TOKEN = os.getenv("MANAGER_TOKEN")

# Headers
daftra_headers = {
    "APIKEY": APIKEY,
    "Content-Type": "application/json"
}

zid_headers = {
    "Authorization": f"Bearer {AUTH_TOKEN}",
    "X-Manager-Token": MANAGER_TOKEN,
    "Accept": "application/json",
}

# Start dates
start_date_utc3 = datetime(2024, 11, 29, 20, 0, 0, tzinfo=timezone.utc)
start_date_utc3_for_others = datetime(2024, 12, 5, 11, 0, 0, tzinfo=timezone.utc)
start_date_utc3_for_new_two = datetime(2024, 12, 25, 11, 0, 0, tzinfo=timezone.utc)
# Target Product IDs
TARGET_PRODUCT_IDS = ["1056856", "1058711", "1058627", "1058530","1065759", "1058162"]

# Retry settings
MAX_RETRIES = 3
BACKOFF_FACTOR = 2


# Aggregation pipeline to filter new transactions
def get_filtered_results():
    pipeline = [
        {
            "$match": {
                "id": {"$in": TARGET_PRODUCT_IDS}
            }
        },
        {
            "$project": {
                "_id": 1,
                "id": 1,
                "name": 1,
                "barcode": 1,
                "transactions": {
                    "$filter": {
                        "input": "$transactions",
                        "as": "transaction",
                        "cond": {
                            "$and": [
                                {
                                    "$gte": [
                                        {
                                            "$dateFromString": {
                                                "dateString": "$$transaction.created",
                                                "timezone": "Asia/Riyadh"
                                            }
                                        },
                                        {
                                            "$cond": {
                                                "if": {"$in": ["$id", ["1058627", "1058530"]]},
                                                "then": start_date_utc3_for_others,
                                                "else": {
                                                    "$cond": {
                                                        "if": {"$in": ["$id", ["1065759", "1058162"]]},
                                                        "then": start_date_utc3_for_new_two,
                                                        "else": start_date_utc3
                                                    }
                                                }
                                            }
                                        }
                                    ]
                                },
                                {"$eq": ["$$transaction.transaction_type", "2"]},
                                {
                                    "$or": [
                                        {"$eq": ["$$transaction.currency_updated", False]},
                                        {"$not": {"$ifNull": ["$$transaction.currency_updated", False]}}
                                    ]
                                }
                            ]
                        }
                    }
                }
            }
        },
    ]
    return list(collection.aggregate(pipeline))

# Function to fetch currency code from the APIs

def fetch_currency_code(order_id, branch_id,transaction_id):
    # For branch IDs other than 5, set currency_code to 'SAR'
    if branch_id != "5":
        print(f"Branch ID {branch_id} {order_id} {transaction_id}: Skipping currency_code fetch and setting currency_code to 'SAR'.")
        return "SAR"  # Return 'SAR' for branch IDs other than 5

    # Retry logic for branch ID 5
    retries = MAX_RETRIES
    while retries > 0:
        try:
            # Daftra API request to get order details
            daftra_request_url = f"{API_URL_ORDERS}?filter[branch_id]={branch_id}&filter[id]={order_id}"
            daftra_response = requests.get(daftra_request_url, headers=daftra_headers)
            daftra_response.raise_for_status()

            data = daftra_response.json().get("data", [])
            if not data:
                print(f"No data found for Order ID {order_id} in Daftra response.")
                return None

            # Extract the 'no' field from the Daftra response
            no_field = data[0].get("no")
            if not no_field:
                print(f"No 'no' field found for Order ID {order_id}.")
                return None

            # Zid API request to fetch currency code
            zid_request_url = API_URL_ORDERS_ZID.format(order_id=no_field)
            zid_response = requests.get(zid_request_url, headers=zid_headers)
            zid_response.raise_for_status()

            currency_code = zid_response.json().get("order", {}).get("currency_code")
            return currency_code

        except requests.RequestException as e:
            retries -= 1
            print(f"Error fetching currency code for Order ID {order_id}: {e}")
            if retries > 0:
                wait_time = BACKOFF_FACTOR * (2 ** (MAX_RETRIES - retries))
                print(f"Retrying... {retries} attempts left. Waiting {wait_time} seconds.")
                time.sleep(wait_time)
            else:
                print(f"All retries exhausted for Order ID {order_id}.")
                return None



# Function to fetch with retries
def fetch_with_retries(url, headers, retries=MAX_RETRIES):
    for attempt in range(retries):
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.RequestException as e:
            print(f"Attempt {attempt + 1} failed: {e}")
            if attempt < retries - 1:
                time.sleep(BACKOFF_FACTOR * (2 ** attempt))
            else:
                raise


# Function to update transactions
def update_transactions():
    filtered_results = get_filtered_results()

    for product in filtered_results:
        transactions = product.get("transactions", [])

        for transaction in transactions:
            transaction_id = str(transaction.get("id"))
            order_id = transaction.get("order_id")
            branch_id = transaction.get("branch_id")

            if transaction.get("currency_updated"):
                print(f"Transaction {transaction_id}: Already processed, skipping.")
                continue

            if not order_id or not branch_id:
                print(f"Skipping transaction {transaction_id}: Missing order_id or branch_id.")
                continue

            currency_code = fetch_currency_code(order_id, branch_id,transaction_id)

            transaction["currency_code"] = currency_code
            transaction["currency_updated"] = True

            result = collection.update_one(
                {"_id": product["_id"], "transactions.id": transaction_id},
                {
                    "$set": {
                        "transactions.$.currency_code": currency_code,
                        "transactions.$.currency_updated": True
                    }
                }
            )

            if result.modified_count:
                print(f"Transaction {transaction_id} updated successfully with currency_code '{currency_code}'.")
            else:
                print(f"No updates made for Transaction {transaction_id}.")


# Function to update sync timestamp
def update_sync_timestamp(sync_type):
    current_timestamp = datetime.utcnow()
    try:
        update_field = 'startAt' if sync_type == 'start' else 'finishAt'
        db['update'].update_one({}, {"$set": {update_field: current_timestamp}}, upsert=True)
        print(f"Sync {sync_type} timestamp {current_timestamp.isoformat()} stored/updated")
    except Exception as error:
        print(f"Error storing {sync_type} timestamp: {error}")


# Function to fetch and store product data
def fetch_and_store_data():
    for product_id in TARGET_PRODUCT_IDS:
        print(f"Fetching product data for ID {product_id}...")
        product_url = f"{API_URL_PRODUCTS}/{product_id}.json"
        product_data = fetch_with_retries(product_url, daftra_headers)

        if product_data and "data" in product_data:
            product = product_data["data"]["Product"]

            print(f"Fetching transactions for product ID {product_id}...")
            all_transactions = []
            page_number = 1

            while True:
                transaction_url = f"{API_URL_TRANSACTIONS}?product_id={product_id}&page={page_number}"
                transaction_data = fetch_with_retries(transaction_url, daftra_headers)

                if transaction_data and "data" in transaction_data:
                    transactions = [record["StockTransaction"] for record in transaction_data["data"]]
                    all_transactions.extend(transactions)

                    if transaction_data.get("pagination", {}).get("next"):
                        page_number += 1
                    else:
                        break
                else:
                    break

            # Fetch the existing product document from the database
            existing_product = collection.find_one({"id": product_id})
            existing_transactions = existing_product.get("transactions", []) if existing_product else []

            # Create a dictionary of existing transactions for quick lookup by transaction ID
            existing_transactions_dict = {str(t["id"]): t for t in existing_transactions}

            # Merge transactions: Retain old ones with currency_updated=True, add new ones
            merged_transactions = []

            for transaction in all_transactions:
                transaction_id = str(transaction["id"])
                if transaction_id in existing_transactions_dict:
                    # Keep the existing transaction if currency_updated=True
                    if existing_transactions_dict[transaction_id].get("currency_updated", False):
                        merged_transactions.append(existing_transactions_dict[transaction_id])
                    else:
                        merged_transactions.append(transaction)
                else:
                    # New transaction, add to the list
                    merged_transactions.append(transaction)

            # Update the product document with merged transactions
            product["transactions"] = merged_transactions

            collection.update_one({"id": product["id"]}, {"$set": product}, upsert=True)
            print(f"Product {product_id} data updated with merged transactions.")



# Scheduler function
def scheduled_job():
    print("\n--- Scheduled job started ---")
    update_sync_timestamp('start')
    fetch_and_store_data()
    update_transactions()
    update_sync_timestamp('finish')
    print("--- Scheduled job completed ---\n")


# Schedule the job every hour
schedule.every(1).hour.do(scheduled_job)

# Keep the script running
if __name__ == "__main__":
    print("Scheduler started. Press Ctrl+C to stop.")
    scheduled_job()  # Run immediately on start
    while True:
        schedule.run_pending()
        time.sleep(1)
# Out:
# Requirement already satisfied: requests==2.31.0 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: pymongo==4.7.2 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (4.7.2)
# Requirement already satisfied: python-dotenv==1.0.1 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: schedule==1.2.1 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\didar\anaconda3\lib\site-packages (from pymongo==4.7.2->-r requirements.txt (line 2)) (2.7.0)
# Scheduler started. Press Ctrl+C to stop.
#
# --- Scheduled job started ---
# Sync start timestamp 2024-12-25T12:37:19.865626 stored/updated
# Fetching product data for ID 1056856...
# Fetching transactions for product ID 1056856...
# Product 1056856 data updated with merged transactions.
# Fetching product data for ID 1058711...
# Fetching transactions for product ID 1058711...
# Product 1058711 data updated with merged transactions.
# Fetching product data for ID 1058627...
# Fetching transactions for product ID 1058627...
# Product 1058627 data updated with merged transactions.
# Fetching product data for ID 1058530...
# Fetching transactions for product ID 1058530...
# Product 1058530 data updated with merged transactions.
# Fetching product data for ID 1065759...
# Fetching transactions for product ID 1065759...
# Product 1065759 data updated with merged transactions.
# Fetching product data for ID 1058162...
# Fetching transactions for product ID 1058162...
# Product 1058162 data updated with merged transactions.
# Transaction 116850 updated successfully with currency_code 'SAR'.
# No updates made for Transaction 116879.
# No updates made for Transaction 116887.
# No updates made for Transaction 116906.
# No updates made for Transaction 116917.
# No updates made for Transaction 116922.
# Branch ID 3 24658 116935: Skipping currency_code fetch and setting currency_code to 'SAR'.
# No updates made for Transaction 116935.
# Branch ID 2 24662 116952: Skipping currency_code fetch and setting currency_code to 'SAR'.
# No updates made for Transaction 116952.
# No updates made for Transaction 116955.
# No updates made for Transaction 116969.
# No updates made for Transaction 116990.
# No updates made for Transaction 116996.
# Branch ID 2 2031 117004: Skipping currency_code fetch and setting currency_code to 'SAR'.
# No updates made for Transaction 117004.
# No updates made for Transaction 117043.
# No updates made for Transaction 117045.
# No updates made for Transaction 117069.
# No updates made for Transaction 117101.
# No updates made for Transaction 117113.
# No updates made for Transaction 117118.
# No updates made for Transaction 117144.
# No updates made for Transaction 117231.
# No updates made for Transaction 117327.
# No updates made for Transaction 117333.
# No updates made for Transaction 117355.
# No updates made for Transaction 117364.
# No updates made for Transaction 117393.
# No updates made for Transaction 117396.
# No updates made for Transaction 117410.
# No updates made for Transaction 117412.
# No updates made for Transaction 117414.
# No updates made for Transaction 117463.
# No updates made for Transaction 117471.
# No updates made for Transaction 117475.
# Transaction 117477 updated successfully with currency_code 'SAR'.
# No updates made for Transaction 117487.
# Transaction 117489 updated successfully with currency_code 'SAR'.
# Transaction 117501 updated successfully with currency_code 'SAR'.
# No updates made for Transaction 117523.
# Transaction 117543 updated successfully with currency_code 'SAR'.
# Transaction 117553 updated successfully with currency_code 'SAR'.
# Transaction 117580 updated successfully with currency_code 'SAR'.
# No updates made for Transaction 117582.
# No updates made for Transaction 117584.
# No updates made for Transaction 117596.
# No updates made for Transaction 117603.
# Branch ID 2 24866 117604: Skipping currency_code fetch and setting currency_code to 'SAR'.
# No updates made for Transaction 117604.
# No updates made for Transaction 117606.
# Transaction 117609 updated successfully with currency_code 'OMR'.
# Branch ID 3 24871 117615: Skipping currency_code fetch and setting currency_code to 'SAR'.
# No updates made for Transaction 117615.
# No updates made for Transaction 117616.
# No updates made for Transaction 117619.
# Transaction 117637 updated successfully with currency_code 'SAR'.
# Transaction 117674 updated successfully with currency_code 'SAR'.
# Transaction 117682 updated successfully with currency_code 'AED'.
# No updates made for Transaction 117693.
# No updates made for Transaction 117710.
# No updates made for Transaction 117713.
# Transaction 117724 updated successfully with currency_code 'AED'.
# Transaction 117731 updated successfully with currency_code 'SAR'.
# Transaction 117767 updated successfully with currency_code 'SAR'.
# Transaction 117770 updated successfully with currency_code 'SAR'.
# Transaction 117774 updated successfully with currency_code 'SAR'.
# Transaction 117777 updated successfully with currency_code 'SAR'.
# No updates made for Transaction 117800.
# No updates made for Transaction 117807.
# No updates made for Transaction 117814.
# No updates made for Transaction 117820.
# No updates made for Transaction 117826.
# No updates made for Transaction 117857.
# No updates made for Transaction 117879.
# No updates made for Transaction 117926.
# No updates made for Transaction 117928.
# No updates made for Transaction 117959.
# No updates made for Transaction 118134.
# No updates made for Transaction 118469.
# No updates made for Transaction 118477.
# No updates made for Transaction 119290.
# No updates made for Transaction 119292.
# No updates made for Transaction 119300.
# No updates made for Transaction 119313.
# No updates made for Transaction 119351.
# No updates made for Transaction 119395.
# No updates made for Transaction 119449.
# No updates made for Transaction 119451.
# No updates made for Transaction 119455.
# No updates made for Transaction 119464.
# No updates made for Transaction 119476.
# No updates made for Transaction 119501.
# No updates made for Transaction 119502.
# No updates made for Transaction 119521.
# No updates made for Transaction 119531.
# No updates made for Transaction 119536.
# Transaction 119541 updated successfully with currency_code 'SAR'.
# No updates made for Transaction 119550.
# No updates made for Transaction 119558.
# No updates made for Transaction 119561.
# No updates made for Transaction 119563.
# No updates made for Transaction 119564.
# No updates made for Transaction 119591.
# No updates made for Transaction 119603.
# No updates made for Transaction 119605.
# No updates made for Transaction 119611.
# No updates made for Transaction 119613.
# No updates made for Transaction 119620.
# Transaction 119651 updated successfully with currency_code 'SAR'.
# No updates made for Transaction 119654.
# No updates made for Transaction 119687.
# No updates made for Transaction 119691.
# Transaction 119699 updated successfully with currency_code 'SAR'.
# Transaction 119701 updated successfully with currency_code 'SAR'.
# Transaction 119861 updated successfully with currency_code 'SAR'.
# Transaction 119891 updated successfully with currency_code 'SAR'.
# Transaction 119901 updated successfully with currency_code 'SAR'.
# No updates made for Transaction 119904.
# No updates made for Transaction 119969.
# No updates made for Transaction 120099.
# No updates made for Transaction 120120.
# No updates made for Transaction 120136.
# No updates made for Transaction 120145.
# No updates made for Transaction 120159.
# No updates made for Transaction 120176.
# No updates made for Transaction 120182.
# No updates made for Transaction 120185.
# No updates made for Transaction 120258.
# Transaction 120572 updated successfully with currency_code 'SAR'.
# No updates made for Transaction 120637.
# No updates made for Transaction 121832.
# No updates made for Transaction 121838.
# No updates made for Transaction 121881.
# No updates made for Transaction 121888.
# No updates made for Transaction 121895.
# No updates made for Transaction 121934.
# Transaction 121950 updated successfully with currency_code 'OMR'.
# No updates made for Transaction 121952.
# Transaction 121985 updated successfully with currency_code 'SAR'.
# No updates made for Transaction 122260.
# No updates made for Transaction 123378.
# No updates made for Transaction 123435.
# Branch ID 2 2096 123475: Skipping currency_code fetch and setting currency_code to 'SAR'.
# No updates made for Transaction 123475.
# No updates made for Transaction 125152.
# No updates made for Transaction 125258.
# No updates made for Transaction 125264.
# No updates made for Transaction 125266.
# No updates made for Transaction 125272.
# Transaction 125291 updated successfully with currency_code 'SAR'.
# Transaction 125343 updated successfully with currency_code 'SAR'.
# No updates made for Transaction 125355.
# No updates made for Transaction 125488.
# No updates made for Transaction 125494.
# No updates made for Transaction 125497.
# No updates made for Transaction 125499.
# Branch ID 3 25911 125612: Skipping currency_code fetch and setting currency_code to 'SAR'.
# No updates made for Transaction 125612.
# No updates made for Transaction 125840.
# No updates made for Transaction 126017.
# No updates made for Transaction 126310.
# No updates made for Transaction 126341.
# No updates made for Transaction 126360.
# No updates made for Transaction 126468.
# No updates made for Transaction 126536.
# No updates made for Transaction 126615.
# No updates made for Transaction 126618.
# No updates made for Transaction 126630.
# No updates made for Transaction 126972.
# No updates made for Transaction 127006.
# No updates made for Transaction 127022.
# Sync finish timestamp 2024-12-25T12:49:00.725619 stored/updated
# --- Scheduled job completed ---
#
#
# --- Scheduled job started ---
# Sync start timestamp 2024-12-25T12:49:00.865591 stored/updated
# Fetching product data for ID 1056856...
# Fetching transactions for product ID 1056856...
# Product 1056856 data updated with merged transactions.
# Fetching product data for ID 1058711...
# Fetching transactions for product ID 1058711...
# Product 1058711 data updated with merged transactions.
# Fetching product data for ID 1058627...
# Fetching transactions for product ID 1058627...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 309
#     307 scheduled_job()  # Run immediately on start
#     308 while True:
# --> 309     schedule.run_pending()
#     310     time.sleep(1)
#
# File c:\Users\didar\anaconda3\Lib\site-packages\schedule\__init__.py:822, in run_pending()
#     818 def run_pending() -> None:
#     819     """Calls :meth:`run_pending <Scheduler.run_pending>` on the
#     820     :data:`default scheduler instance <default_scheduler>`.
#     821     """
# --> 822     default_scheduler.run_pending()
#
# File c:\Users\didar\anaconda3\Lib\site-packages\schedule\__init__.py:100, in Scheduler.run_pending(self)
#      98 runnable_jobs = (job for job in self.jobs if job.should_run)
#      99 for job in sorted(runnable_jobs):
# --> 100     self._run_job(job)
#
# File c:\Users\didar\anaconda3\Lib\site-packages\schedule\__init__.py:172, in Scheduler._run_job(self, job)
#     171 def _run_job(self, job: "Job") -> None:
# --> 172     ret = job.run()
#     173     if isinstance(ret, CancelJob) or ret is CancelJob:
#     174         self.cancel_job(job)
#
# File c:\Users\didar\anaconda3\Lib\site-packages\schedule\__init__.py:693, in Job.run(self)
#     690     return CancelJob
#     692 logger.debug("Running job %s", self)
# --> 693 ret = self.job_func()
#     694 self.last_run = datetime.datetime.now()
#     695 self._schedule_next_run()
#
# Cell In[2], line 296, in scheduled_job()
#     294 print("\n--- Scheduled job started ---")
#     295 update_sync_timestamp('start')
# --> 296 fetch_and_store_data()
#     297 update_transactions()
#     298 update_sync_timestamp('finish')
#
# Cell In[6], line 248, in fetch_and_store_data()
#     246 while True:
#     247     transaction_url = f"{API_URL_TRANSACTIONS}?product_id={product_id}&page={page_number}"
# --> 248     transaction_data = fetch_with_retries(transaction_url, daftra_headers)
#     250     if transaction_data and "data" in transaction_data:
#     251         transactions = [record["StockTransaction"] for record in transaction_data["data"]]
#
# Cell In[6], line 169, in fetch_with_retries(url, headers, retries)
#     167 for attempt in range(retries):
#     168     try:
# --> 169         response = requests.get(url, headers=headers)
#     170         response.raise_for_status()
#     171         return response.json()
#
# File c:\Users\didar\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\didar\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\didar\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\didar\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\didar\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\didar\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\didar\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\didar\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\Users\didar\anaconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File c:\Users\didar\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\didar\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\didar\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\didar\anaconda3\Lib\ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\didar\anaconda3\Lib\ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
