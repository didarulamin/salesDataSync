# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: requests==2.31.0 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: pymongo==4.7.2 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (4.7.2)
# Requirement already satisfied: python-dotenv==1.0.1 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: schedule==1.2.1 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\didar\anaconda3\lib\site-packages (from pymongo==4.7.2->-r requirements.txt (line 2)) (2.7.0)

# %%
# !pip install -r requirements.txt
import requests
from pymongo import MongoClient, UpdateOne
import time
from datetime import datetime, timezone
import schedule
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# MongoDB Connection
MONGO_URI = os.getenv("MONGO_URI")
DATABASE_NAME = "Daftra"
COLLECTION_NAME = "products"

client = MongoClient(MONGO_URI)
db = client[DATABASE_NAME]
collection = db[COLLECTION_NAME]

# API Configuration
API_URL_PRODUCTS = "https://amamamed.daftra.com/api2/products"
API_URL_TRANSACTIONS = "https://amamamed.daftra.com/api2/stock_transactions"
API_URL_ORDERS = "https://amamamed.daftra.com/v2/api/entity/invoice/list/-1"
API_URL_ORDERS_ZID = "https://api.zid.sa/v1/managers/store/orders/{order_id}/view"

# Environment Variables
APIKEY = os.getenv("APIKEY")
AUTH_TOKEN = os.getenv("AUTH_TOKEN")
MANAGER_TOKEN = os.getenv("MANAGER_TOKEN")

# Headers
daftra_headers = {
    "APIKEY": APIKEY,
    "Content-Type": "application/json"
}

zid_headers = {
    "Authorization": f"Bearer {AUTH_TOKEN}",
    "X-Manager-Token": MANAGER_TOKEN,
    "Accept": "application/json",
}

# Start dates
start_date_utc3 = datetime(2024, 11, 29, 20, 0, 0, tzinfo=timezone.utc)
start_date_utc3_for_others = datetime(2024, 12, 5, 11, 0, 0, tzinfo=timezone.utc)
start_date_utc3_for_new_two = datetime(2024, 12, 25, 11, 0, 0, tzinfo=timezone.utc)
start_date_utc3_for_new_one= datetime(2025, 1, 7, 20, 0, 0, tzinfo=timezone.utc)
# Target Product IDs
TARGET_PRODUCT_IDS = ["1056856", "1058711", "1058627", "1058530","1065759", "1058162","1056857"]

# Retry settings
MAX_RETRIES = 3
BACKOFF_FACTOR = 2


# Aggregation pipeline to filter new transactions
def get_filtered_results():
    pipeline = [
        {
            "$match": {
                "id": {"$in": TARGET_PRODUCT_IDS}
            }
        },
        {
            "$project": {
                "_id": 1,
                "id": 1,
                "name": 1,
                "barcode": 1,
                "transactions": {
                    "$filter": {
                        "input": "$transactions",
                        "as": "transaction",
                        "cond": {
                            "$and": [
                                {
                                    "$gte": [
                                        {
                                            "$dateFromString": {
                                                "dateString": "$$transaction.created",
                                                "timezone": "Asia/Riyadh"
                                            }
                                        },
                                       {
                                            "$cond": {
                                                "if": {"$in": ["$id", ["1058627", "1058530"]]},
                                                "then": start_date_utc3_for_others,
                                                "else": {
                                                    "$cond": {
                                                        "if": {"$in": ["$id", ["1065759", "1058162"]]},
                                                        "then": start_date_utc3_for_new_two,
                                                        "else": {
                                                            "$cond": {
                                                                "if": {"$eq": ["$id", "1056857"]},
                                                                "then": start_date_utc3_for_new_one,
                                                                "else": start_date_utc3
                                                            }
                                                        }
                                                    }
                                                }
                                            }
                                        }
                                    ]
                                },
                                {"$eq": ["$$transaction.transaction_type", "2"]},
                                {
                                    "$or": [
                                        {"$eq": ["$$transaction.currency_updated", False]},
                                        {"$not": {"$ifNull": ["$$transaction.currency_updated", False]}}
                                    ]
                                }
                            ]
                        }
                    }
                }
            }
        },
    ]
    return list(collection.aggregate(pipeline))

# Function to fetch currency code from the APIs

def fetch_currency_code(order_id, branch_id,transaction_id):
    # For branch IDs other than 5, set currency_code to 'SAR'
    if branch_id != "5":
        print(f"Branch ID {branch_id} {order_id} {transaction_id}: Skipping currency_code fetch and setting currency_code to 'SAR'.")
        return "SAR"  # Return 'SAR' for branch IDs other than 5

    # Retry logic for branch ID 5
    retries = MAX_RETRIES
    while retries > 0:
        try:
            # Daftra API request to get order details
            daftra_request_url = f"{API_URL_ORDERS}?filter[branch_id]={branch_id}&filter[id]={order_id}"
            daftra_response = requests.get(daftra_request_url, headers=daftra_headers)
            daftra_response.raise_for_status()

            data = daftra_response.json().get("data", [])
            if not data:
                print(f"No data found for Order ID {order_id} in Daftra response.")
                return None

            # Extract the 'no' field from the Daftra response
            no_field = data[0].get("no")
            if not no_field:
                print(f"No 'no' field found for Order ID {order_id}.")
                return None

            # Zid API request to fetch currency code
            zid_request_url = API_URL_ORDERS_ZID.format(order_id=no_field)
            zid_response = requests.get(zid_request_url, headers=zid_headers)
            zid_response.raise_for_status()

            currency_code = zid_response.json().get("order", {}).get("currency_code")
            return currency_code

        except requests.RequestException as e:
            retries -= 1
            print(f"Error fetching currency code for Order ID {order_id}: {e}")
            if retries > 0:
                wait_time = BACKOFF_FACTOR * (2 ** (MAX_RETRIES - retries))
                print(f"Retrying... {retries} attempts left. Waiting {wait_time} seconds.")
                time.sleep(wait_time)
            else:
                print(f"All retries exhausted for Order ID {order_id}.")
                return None



# Function to fetch with retries
def fetch_with_retries(url, headers, retries=MAX_RETRIES):
    for attempt in range(retries):
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.RequestException as e:
            print(f"Attempt {attempt + 1} failed: {e}")
            if attempt < retries - 1:
                time.sleep(BACKOFF_FACTOR * (2 ** attempt))
            else:
                raise


# Function to update transactions
def update_transactions():
    filtered_results = get_filtered_results()

    for product in filtered_results:
        transactions = product.get("transactions", [])

        for transaction in transactions:
            transaction_id = str(transaction.get("id"))
            order_id = transaction.get("order_id")
            branch_id = transaction.get("branch_id")

            if transaction.get("currency_updated"):
                print(f"Transaction {transaction_id}: Already processed, skipping.")
                continue

            if not order_id or not branch_id:
                print(f"Skipping transaction {transaction_id}: Missing order_id or branch_id.")
                continue

            currency_code = fetch_currency_code(order_id, branch_id,transaction_id)

            transaction["currency_code"] = currency_code
            transaction["currency_updated"] = True

            result = collection.update_one(
                {"_id": product["_id"], "transactions.id": transaction_id},
                {
                    "$set": {
                        "transactions.$.currency_code": currency_code,
                        "transactions.$.currency_updated": True
                    }
                }
            )

            if result.modified_count:
                print(f"Transaction {transaction_id} updated successfully with currency_code '{currency_code}'.")
            else:
                print(f"No updates made for Transaction {transaction_id}.")


# Function to update sync timestamp
def update_sync_timestamp(sync_type):
    current_timestamp = datetime.utcnow()
    try:
        update_field = 'startAt' if sync_type == 'start' else 'finishAt'
        db['update'].update_one({}, {"$set": {update_field: current_timestamp}}, upsert=True)
        print(f"Sync {sync_type} timestamp {current_timestamp.isoformat()} stored/updated")
    except Exception as error:
        print(f"Error storing {sync_type} timestamp: {error}")


# Function to fetch and store product data
def fetch_and_store_data():
    for product_id in TARGET_PRODUCT_IDS:
        print(f"Fetching product data for ID {product_id}...")
        product_url = f"{API_URL_PRODUCTS}/{product_id}.json"
        product_data = fetch_with_retries(product_url, daftra_headers)

        if product_data and "data" in product_data:
            product = product_data["data"]["Product"]

            print(f"Fetching transactions for product ID {product_id}...")
            all_transactions = []
            page_number = 1

            while True:
                transaction_url = f"{API_URL_TRANSACTIONS}?product_id={product_id}&page={page_number}"
                transaction_data = fetch_with_retries(transaction_url, daftra_headers)

                if transaction_data and "data" in transaction_data:
                    transactions = [record["StockTransaction"] for record in transaction_data["data"]]
                    all_transactions.extend(transactions)

                    if transaction_data.get("pagination", {}).get("next"):
                        page_number += 1
                    else:
                        break
                else:
                    break

            # Fetch the existing product document from the database
            existing_product = collection.find_one({"id": product_id})
            existing_transactions = existing_product.get("transactions", []) if existing_product else []

            # Create a dictionary of existing transactions for quick lookup by transaction ID
            existing_transactions_dict = {str(t["id"]): t for t in existing_transactions}

            # Merge transactions: Retain old ones with currency_updated=True, add new ones
            merged_transactions = []

            for transaction in all_transactions:
                transaction_id = str(transaction["id"])
                if transaction_id in existing_transactions_dict:
                    # Keep the existing transaction if currency_updated=True
                    if existing_transactions_dict[transaction_id].get("currency_updated", False):
                        merged_transactions.append(existing_transactions_dict[transaction_id])
                    else:
                        merged_transactions.append(transaction)
                else:
                    # New transaction, add to the list
                    merged_transactions.append(transaction)

            # Update the product document with merged transactions
            product["transactions"] = merged_transactions

            collection.update_one({"id": product["id"]}, {"$set": product}, upsert=True)
            print(f"Product {product_id} data updated with merged transactions.")



# Scheduler function
def scheduled_job():
    print("\n--- Scheduled job started ---")
    update_sync_timestamp('start')
    fetch_and_store_data()
    update_transactions()
    update_sync_timestamp('finish')
    print("--- Scheduled job completed ---\n")


# Schedule the job every hour
schedule.every(1).hour.do(scheduled_job)

# Keep the script running
if __name__ == "__main__":
    print("Scheduler started. Press Ctrl+C to stop.")
    scheduled_job()  # Run immediately on start
    while True:
        schedule.run_pending()
        time.sleep(1)
# Out:
# Requirement already satisfied: requests==2.31.0 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: pymongo==4.7.2 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (4.7.2)
# Requirement already satisfied: python-dotenv==1.0.1 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: schedule==1.2.1 in c:\users\didar\anaconda3\lib\site-packages (from -r requirements.txt (line 4)) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\didar\anaconda3\lib\site-packages (from requests==2.31.0->-r requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\didar\anaconda3\lib\site-packages (from pymongo==4.7.2->-r requirements.txt (line 2)) (2.7.0)
# Scheduler started. Press Ctrl+C to stop.
#
# --- Scheduled job started ---
# Sync start timestamp 2025-01-08T12:41:35.318297 stored/updated
# Fetching product data for ID 1056856...
# Fetching transactions for product ID 1056856...
# Product 1056856 data updated with merged transactions.
# Fetching product data for ID 1058711...
# Fetching transactions for product ID 1058711...
# Product 1058711 data updated with merged transactions.
# Fetching product data for ID 1058627...
# Fetching transactions for product ID 1058627...
# Product 1058627 data updated with merged transactions.
# Fetching product data for ID 1058530...
# Fetching transactions for product ID 1058530...
# Product 1058530 data updated with merged transactions.
# Fetching product data for ID 1065759...
# Fetching transactions for product ID 1065759...
# Product 1065759 data updated with merged transactions.
# Fetching product data for ID 1058162...
# Fetching transactions for product ID 1058162...
# Product 1058162 data updated with merged transactions.
# Fetching product data for ID 1056857...
# Fetching transactions for product ID 1056857...
# Product 1056857 data updated with merged transactions.
# Transaction 146078 updated successfully with currency_code 'SAR'.
# Transaction 146079 updated successfully with currency_code 'SAR'.
# Transaction 146083 updated successfully with currency_code 'SAR'.
# Transaction 146088 updated successfully with currency_code 'SAR'.
# Transaction 146098 updated successfully with currency_code 'SAR'.
# Transaction 145525 updated successfully with currency_code 'SAR'.
# Transaction 145527 updated successfully with currency_code 'SAR'.
# Transaction 145529 updated successfully with currency_code 'AED'.
# Transaction 145537 updated successfully with currency_code 'AED'.
# Transaction 145543 updated successfully with currency_code 'SAR'.
# Transaction 145547 updated successfully with currency_code 'SAR'.
# Transaction 145549 updated successfully with currency_code 'SAR'.
# Transaction 145551 updated successfully with currency_code 'SAR'.
# Transaction 145578 updated successfully with currency_code 'SAR'.
# Transaction 145580 updated successfully with currency_code 'KWD'.
# Transaction 145588 updated successfully with currency_code 'SAR'.
# Transaction 145590 updated successfully with currency_code 'SAR'.
# Transaction 145594 updated successfully with currency_code 'SAR'.
# Transaction 145597 updated successfully with currency_code 'AED'.
# Transaction 145599 updated successfully with currency_code 'AED'.
# Transaction 145602 updated successfully with currency_code 'AED'.
# Transaction 145605 updated successfully with currency_code 'SAR'.
# Transaction 145607 updated successfully with currency_code 'SAR'.
# Transaction 145609 updated successfully with currency_code 'SAR'.
# Transaction 145611 updated successfully with currency_code 'SAR'.
# Transaction 145613 updated successfully with currency_code 'SAR'.
# Transaction 145624 updated successfully with currency_code 'SAR'.
# Transaction 145625 updated successfully with currency_code 'AED'.
# Transaction 145633 updated successfully with currency_code 'SAR'.
# Transaction 145638 updated successfully with currency_code 'SAR'.
# Transaction 145640 updated successfully with currency_code 'SAR'.
# Transaction 145641 updated successfully with currency_code 'KWD'.
# Transaction 145642 updated successfully with currency_code 'SAR'.
# Transaction 145644 updated successfully with currency_code 'SAR'.
# Transaction 145646 updated successfully with currency_code 'SAR'.
# Transaction 145648 updated successfully with currency_code 'KWD'.
# Transaction 145659 updated successfully with currency_code 'SAR'.
# Transaction 145667 updated successfully with currency_code 'SAR'.
# Transaction 145669 updated successfully with currency_code 'SAR'.
# Transaction 145670 updated successfully with currency_code 'SAR'.
# Transaction 145672 updated successfully with currency_code 'SAR'.
# Transaction 145674 updated successfully with currency_code 'QAR'.
# Transaction 145677 updated successfully with currency_code 'SAR'.
# Transaction 145680 updated successfully with currency_code 'SAR'.
# Transaction 145682 updated successfully with currency_code 'SAR'.
# Transaction 145690 updated successfully with currency_code 'SAR'.
# Transaction 145692 updated successfully with currency_code 'SAR'.
# Transaction 145694 updated successfully with currency_code 'AED'.
# Transaction 145696 updated successfully with currency_code 'SAR'.
# Transaction 145698 updated successfully with currency_code 'SAR'.
# Transaction 145703 updated successfully with currency_code 'SAR'.
# Transaction 145706 updated successfully with currency_code 'SAR'.
# Transaction 145707 updated successfully with currency_code 'SAR'.
# Transaction 145711 updated successfully with currency_code 'SAR'.
# Transaction 145714 updated successfully with currency_code 'SAR'.
# Transaction 145719 updated successfully with currency_code 'AED'.
# Transaction 145721 updated successfully with currency_code 'SAR'.
# Transaction 145723 updated successfully with currency_code 'SAR'.
# Transaction 145725 updated successfully with currency_code 'SAR'.
# Transaction 145730 updated successfully with currency_code 'KWD'.
# Transaction 145732 updated successfully with currency_code 'SAR'.
# Transaction 145734 updated successfully with currency_code 'SAR'.
# Transaction 145737 updated successfully with currency_code 'SAR'.
# Transaction 145738 updated successfully with currency_code 'SAR'.
# Transaction 145742 updated successfully with currency_code 'SAR'.
# Transaction 145744 updated successfully with currency_code 'KWD'.
# Transaction 145747 updated successfully with currency_code 'AED'.
# Transaction 145752 updated successfully with currency_code 'SAR'.
# Transaction 145754 updated successfully with currency_code 'SAR'.
# Transaction 145757 updated successfully with currency_code 'SAR'.
# Transaction 145759 updated successfully with currency_code 'SAR'.
# Transaction 145761 updated successfully with currency_code 'SAR'.
# Transaction 145763 updated successfully with currency_code 'AED'.
# Transaction 145767 updated successfully with currency_code 'AED'.
# Transaction 145769 updated successfully with currency_code 'AED'.
# Transaction 145772 updated successfully with currency_code 'SAR'.
# Transaction 145775 updated successfully with currency_code 'SAR'.
# Transaction 145777 updated successfully with currency_code 'SAR'.
# Transaction 145780 updated successfully with currency_code 'AED'.
# Transaction 145783 updated successfully with currency_code 'AED'.
# Transaction 145787 updated successfully with currency_code 'SAR'.
# Transaction 145790 updated successfully with currency_code 'AED'.
# Transaction 145793 updated successfully with currency_code 'SAR'.
# Transaction 145795 updated successfully with currency_code 'SAR'.
# Transaction 145798 updated successfully with currency_code 'SAR'.
# Transaction 145800 updated successfully with currency_code 'SAR'.
# Transaction 145802 updated successfully with currency_code 'SAR'.
# Transaction 145812 updated successfully with currency_code 'SAR'.
# Transaction 145818 updated successfully with currency_code 'KWD'.
# Transaction 145823 updated successfully with currency_code 'AED'.
# Transaction 145828 updated successfully with currency_code 'SAR'.
# Transaction 145830 updated successfully with currency_code 'AED'.
# Transaction 145832 updated successfully with currency_code 'SAR'.
# Transaction 145836 updated successfully with currency_code 'SAR'.
# Transaction 145840 updated successfully with currency_code 'SAR'.
# Transaction 145842 updated successfully with currency_code 'SAR'.
# Transaction 145844 updated successfully with currency_code 'SAR'.
# Transaction 145846 updated successfully with currency_code 'SAR'.
# Transaction 145849 updated successfully with currency_code 'SAR'.
# Transaction 145851 updated successfully with currency_code 'SAR'.
# Transaction 145853 updated successfully with currency_code 'AED'.
# Transaction 145856 updated successfully with currency_code 'SAR'.
# Transaction 145859 updated successfully with currency_code 'SAR'.
# Transaction 145861 updated successfully with currency_code 'SAR'.
# Transaction 145865 updated successfully with currency_code 'AED'.
# Transaction 145867 updated successfully with currency_code 'AED'.
# Transaction 145868 updated successfully with currency_code 'AED'.
# Transaction 145871 updated successfully with currency_code 'SAR'.
# Transaction 145873 updated successfully with currency_code 'QAR'.
# Transaction 145876 updated successfully with currency_code 'SAR'.
# Transaction 145878 updated successfully with currency_code 'SAR'.
# Transaction 145889 updated successfully with currency_code 'SAR'.
# Transaction 145895 updated successfully with currency_code 'QAR'.
# Transaction 145898 updated successfully with currency_code 'OMR'.
# Transaction 145912 updated successfully with currency_code 'AED'.
# Transaction 145914 updated successfully with currency_code 'AED'.
# Transaction 145918 updated successfully with currency_code 'SAR'.
# Transaction 145920 updated successfully with currency_code 'SAR'.
# Transaction 145923 updated successfully with currency_code 'SAR'.
# Transaction 145925 updated successfully with currency_code 'SAR'.
# Transaction 145927 updated successfully with currency_code 'SAR'.
# Transaction 145933 updated successfully with currency_code 'SAR'.
# Transaction 145935 updated successfully with currency_code 'SAR'.
# Transaction 145937 updated successfully with currency_code 'OMR'.
# Transaction 145939 updated successfully with currency_code 'SAR'.
# Branch ID 2 33126 145943: Skipping currency_code fetch and setting currency_code to 'SAR'.
# Transaction 145943 updated successfully with currency_code 'SAR'.
# Transaction 145946 updated successfully with currency_code 'SAR'.
# Transaction 145953 updated successfully with currency_code 'SAR'.
# Transaction 145955 updated successfully with currency_code 'SAR'.
# Transaction 145957 updated successfully with currency_code 'KWD'.
# Transaction 145961 updated successfully with currency_code 'SAR'.
# Transaction 145964 updated successfully with currency_code 'SAR'.
# Transaction 145966 updated successfully with currency_code 'SAR'.
# Transaction 145968 updated successfully with currency_code 'SAR'.
# Transaction 145977 updated successfully with currency_code 'SAR'.
# Transaction 145979 updated successfully with currency_code 'AED'.
# Transaction 145981 updated successfully with currency_code 'AED'.
# Transaction 145983 updated successfully with currency_code 'SAR'.
# Transaction 145988 updated successfully with currency_code 'SAR'.
# Transaction 145994 updated successfully with currency_code 'AED'.
# Transaction 145999 updated successfully with currency_code 'AED'.
# Transaction 146003 updated successfully with currency_code 'IQD'.
# Transaction 146006 updated successfully with currency_code 'SAR'.
# Transaction 146008 updated successfully with currency_code 'SAR'.
# Transaction 146015 updated successfully with currency_code 'OMR'.
# Transaction 146034 updated successfully with currency_code 'SAR'.
# Transaction 146070 updated successfully with currency_code 'SAR'.
# Transaction 146080 updated successfully with currency_code 'SAR'.
# Transaction 146084 updated successfully with currency_code 'SAR'.
# Transaction 146089 updated successfully with currency_code 'SAR'.
# Transaction 146099 updated successfully with currency_code 'SAR'.
# Sync finish timestamp 2025-01-08T12:55:13.562347 stored/updated
# --- Scheduled job completed ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 317
#     315 while True:
#     316     schedule.run_pending()
# --> 317     time.sleep(1)
#
# KeyboardInterrupt:
